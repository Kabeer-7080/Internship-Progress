# %%
# ShopSense AI – Customer Satisfaction Prediction System
## Individual Machine Learning Project
### Phase 2 – Day 19

# %%
# Import Required Libraries

import pandas as pd
import numpy as np

# %%
# Load the Dataset

import pandas as pd

df = pd.read_csv("/content/E-commerce Customer Behavior - Sheet1.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# Display the First Five Records

df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
# Display the Dataset Shape

print("Number of Rows and Columns:", df.shape)
# Out:
# Number of Rows and Columns: (350, 11)

# %%
# Display Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
# Feature Description Table

feature_description = pd.DataFrame({
    "Feature": [
        "Customer ID",
        "Gender",
        "Age",
        "City",
        "Membership Type",
        "Total Spend",
        "Items Purchased",
        "Average Rating",
        "Discount Applied",
        "Days Since Last Purchase",
        "Satisfaction Level"
    ],
    "Description": [
        "Unique customer identifier",
        "Customer gender",
        "Age of the customer",
        "Customer city",
        "Membership category",
        "Total amount spent by the customer",
        "Number of items purchased",
        "Average rating given by the customer",
        "Discount applied to the purchase",
        "Days since the customer's last purchase",
        "Target variable representing customer satisfaction"
    ]
})

feature_description
# Out:
#                      Feature  \
# 0                Customer ID
# 1                     Gender
# 2                        Age
# 3                       City
# 4            Membership Type
# 5                Total Spend
# 6            Items Purchased
# 7             Average Rating
# 8           Discount Applied
# 9   Days Since Last Purchase
# 10        Satisfaction Level
#
#                                           Description
# 0                          Unique customer identifier
# 1                                     Customer gender
# 2                                 Age of the customer
# 3                                       Customer city
# 4                                 Membership category
# 5                  Total amount spent by the customer
# 6                           Number of items purchased
# 7                Average rating given by the customer
# 8                    Discount applied to the purchase
# 9             Days since the customer's last purchase
# ...

# %%
# Generate Summary Statistics

df.describe()
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   350.000000  350.000000   350.000000       350.000000      350.000000
# mean    275.500000   33.597143   845.381714        12.600000        4.019143
# std     101.180532    4.870882   362.058695         4.155984        0.580539
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.250000   30.000000   502.000000         9.000000        3.500000
# 50%     275.500000   32.500000   775.200000        12.000000        4.100000
# 75%     362.750000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                350.000000
# mean                  26.588571
# std                   13.440813
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...
